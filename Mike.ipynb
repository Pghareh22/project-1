# %%
import pandas as pd
import numpy as np

#####  !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!  #####
## !!! My csv file is not named the same as yours !!!

traffic_data_to_load = "Traffic_Violations (1).csv"

traffic_data = pd.read_csv(traffic_data_to_load)



## Choose only the rows that were tiketed for cellphone use and 
## contributed to an accident.

cell_phone_accidents = traffic_data[(traffic_data['Charge'] == '21-1124.2(d2)') & (traffic_data['Contributed To Accident'] == 'Yes')]
cell_phone_data = traffic_data[(traffic_data['Charge'] == '21-1124.2(d2)')]

## Overview of which gender is cited for cell phone use
## can easily addapt to look at race
male_violations = len(cell_phone_data[(cell_phone_data['Gender'] == 'M')])
female_violations = len(cell_phone_data[(cell_phone_data['Gender'] == 'F')])
gender_summary_df = pd.DataFrame({'Gender': ['Male', 'Female'], 'Violations': [male_violations, female_violations], 
                          'Percentage of Total':[round(male_violations/len(cell_phone_data)*100,3), round(female_violations/len(cell_phone_data)*100,3)]})


## Drop needless columns
cleaned_cell_phone = cell_phone_accidents.drop(columns = ['VehicleType', 'Fatal', 'HAZMAT', 'Commercial Vehicle', 'Work Zone', 'Alcohol', 'Driver City', 'Agency', 'Driver State', 'State', 'Commercial License', 'Year', 'Make', 'Accident', 'Article', 'Belts', 'Arrest Type', 'DL State', 'Color', 'Model', 'Description'])


## Count the number of violations per race ##
race_asian = len(cleaned_cell_phone[(cleaned_cell_phone['Race'] == 'ASIAN')])
race_native_am = len(cleaned_cell_phone[(cleaned_cell_phone['Race'] == 'NATIVE AMERICAN')])
race_white = len(cleaned_cell_phone[(cleaned_cell_phone['Race'] == 'WHITE')])
race_black = len(cleaned_cell_phone[(cleaned_cell_phone['Race'] == 'BLACK')])
race_hispanic = len(cleaned_cell_phone[(cleaned_cell_phone['Race'] == 'HISPANIC')])
race_other = len(cleaned_cell_phone[(cleaned_cell_phone['Race'] == 'OTHER')])

## Create DataFrame that compares the 
## percentage of violations with the percentage of the population.
## This shows which groups may be over/under ticketed.
race_summary_df = pd.DataFrame({'Race': ['Asian', 'Native American', 'White', 'Black', 'Hispanic', 'Other'], 
                        'Violations': [race_asian, race_native_am, race_white, race_black, race_hispanic, race_other], 
                       'Percent of Violations': [round(race_asian/102*100,3), round(race_native_am/102*100,3), round(race_white/102*100,3), round(race_black/102*100,3), round(race_hispanic/102*100,3), round(race_other/102*100,3)  ],
                       'Percent of Population': [4.8, 0.9, 72.4, 12.6, 16.3, 6.2]})
## There are some number plugged un there instead of programatically inserted.
## This shoud change.



## The Dataframes to analyze:                    

#race_summary_df
#gender_summary_df

# %%
race_summary_df
# Out:
#               Race  Violations  Percent of Violations  Percent of Population
# 0            Asian          10                  9.804                    4.8
# 1  Native American           2                  1.961                    0.9
# 2            White          68                 66.667                   72.4
# 3            Black          37                 36.275                   12.6
# 4         Hispanic          16                 15.686                   16.3
# 5            Other          10                  9.804                    6.2

# %%
gender_summary_df
# Out:
#    Gender  Violations  Percentage of Total
# 0    Male       19404                 57.4
# 1  Female       14401                 42.6

# %%
traffic_data['Description'].value_counts()
# Out:
# DRIVER FAILURE TO OBEY PROPERLY PLACED TRAFFIC CONTROL DEVICE INSTRUCTIONS                              110673
# FAILURE TO DISPLAY REGISTRATION CARD UPON DEMAND BY POLICE OFFICER                                       65053
# DRIVING VEHICLE ON HIGHWAY WITH SUSPENDED REGISTRATION                                                   45598
# FAILURE OF INDIVIDUAL DRIVING ON HIGHWAY TO DISPLAY LICENSE TO UNIFORMED POLICE ON DEMAND                35909
# DRIVER USING HANDS TO USE HANDHELD TELEPHONE WHILEMOTOR VEHICLE IS IN MOTION                             33371
# DISPLAYING EXPIRED REGISTRATION PLATE ISSUED BY ANY STATE                                                32067
# DRIVER FAILURE TO STOP AT STOP SIGN LINE                                                                 30773
# PERSON DRIVING MOTOR VEHICLE ON HIGHWAY OR PUBLIC USE PROPERTY ON SUSPENDED LICENSE AND PRIVILEGE        27704
# DRIVING VEHICLE ON HIGHWAY WITHOUT CURRENT REGISTRATION PLATES AND VALIDATION TABS                       22285
# EXCEEDING THE POSTED SPEED LIMIT OF 40 MPH                                                               21924
# EXCEEDING THE POSTED SPEED LIMIT OF 30 MPH                                                               21684
# FAILURE OF VEH. ON HWY. TO DISPLAY LIGHTED LAMPS, ILLUMINATING DEVICE IN UNFAVORABLE VISIBILITY COND     19116
# STOP LIGHTS (*)                                                                                          18866
# DRIVING MOTOR VEHICLE ON HIGHWAY WITHOUT REQUIRED LICENSE AND AUTHORIZATION                              18494
# OPERATOR NOT RESTRAINED BY SEATBELT                                                                      18344
# DRIVER CHANGING LANES WHEN UNSAFE                                                                        18309
# NEGLIGENT DRIVING VEHICLE IN CARELESS AND IMPRUDENT MANNER ENDANGERING PROPERTY, LIFE AND PERSON         18049
# DRIVING VEHICLE WHILE UNDER THE INFLUENCE OF ALCOHOL                                                     16888
# EXCEEDING THE POSTED SPEED LIMIT OF 35 MPH                                                               16115
# FAILURE OF LICENSEE TO NOTIFY ADMINISTRATION OF CHANGE OF ADDRESS WITHIN 30 DAYS                         15676
# DRIVER FAILURE TO STOP AT STEADY CIRCULAR RED SIGNAL                                                     15204
# DRIVING WHILE IMPAIRED BY ALCOHOL                                                                        15099
# FAILURE TO ATTACH VEHICLE REGISTRATION PLATES AT FRONT AND REAR                                          14862
# DRIVING VEH. W/O ADEQUATE REAR REG. PLATE ILLUMINATION                                                   14689
# DRIVER FAIL TO STOP AT FLASHING RED TRAFFIC SIGNAL STOP LINE                                             13841
# FAILURE TO DISPLAY TWO LIGHTED FRONT LAMPS WHEN REQUIRED                                                 13446
# FAILURE TO STOP AT STOP SIGN                                                                             13441
# EXCEEDING MAXIMUM SPEED: 39 MPH IN A POSTED 30 MPH ZONE                                                  12791
# FAILURE TO CONTROL VEHICLE SPEED ON HIGHWAY TO AVOID COLLISION                                           12605
# OPERATING VEHICLE ON HIGHWAY WITH UNAUTHORIZED WINDOW TINTING MATERIAL                                   11804
#                                                                                                          ...
# DRIVING VEH W/ TV-TYPE VIDEO DISP EQUIP THAT IS ON AND VISIBLE TO THE DRIVER ON HWY                          1
# DRIVING UNSAFE VEH. ON HWY. 19% WINDOW TINT, IMPROPER COLORED TURN SIGNALS                                   1
# FAILURE OF DRIVER TO DRIVE TO CURB UPON SIGNAL BY EMERGENCY / POLICE VEH.                                    1
# DRIVING VEH. WITH WINDOW VIEW OBSTRUCTED BY MATERIAL                                                         1
# DRIVING WHILE LIC. SUSP. UNDE 16-206A2                                                                       1
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRUDENT SPEED ON HIGHWAY  85MPH                                  1
# SMOKING LIGHTED TOBACCO PRODUCTS IN TRANSIT FACILITY                                                         1
# BRAKE HOSES NOT SECURED AGAINST DAMAGE, AXLES 3 & 4                                                          1
# USE LAMPS ON MOTOR VEH. CHANGING ORIGINAL DESIGN, PERFORMANCE                                                1
# KNOWINGLY DRIVING UININSURED VEHICLE                                                                         1
# FAIL OF DRIVER,ATTENDED PROPER )ACCIDENT TO FURNISH REQ ID & LIC                                             1
# INOPERABLE MARKER LAMPS                                                                                      1
# REAR ID MISSING                                                                                              1
# DRIVER FAILURE TO YIELD RIGHT-OF-WAY TO VEH. UPON EMERGING FROM DRIVEWAY OF BUILDING                         1
# MODIFYING EXHAUST SYSTEM, NOISE ABATEMENT DEVICEON MOTOR VEH. CAUSING EXCESSIVE NOISE                        1
# REVERSE LAMP AND LEFT REAR ID LIGHT INOPERATIVE                                                              1
# DRIVING WITH LICENSE                                                                                         1
# DRIVER READING TEXT,ELECTRONIC  WHILE OPER. VEH. IN TRAVEL PORTION OF HWY                                    1
# DRIVING VEH  ON HWY WITH  LAMP IMPROPERLY DISPLAYING WHITE LIGHT FROM REAR                                   1
# DRIVING VEHICLE IN EXCESS OF REASONABLE AND PRUDENT SPEED ON HIGHWAY 98/60 ZONE                              1
# DISPLAYING REG. PLATE ISSUED TO ANOTHER PERSON                                                               1
# failure to return to and remain at scene                                                                     1
# FAILURE OF VEH. DRIVER TO FURNISH REQ'D WRITTEN ID INFO ON UNATTENEDED DAMAGED VEH                           1
# DRIVER USING HANDS TO USE HANDHELD TELEPHONE WHILEMOTOR VEHICLE IS IN MOTION \                               1
# DRIVING WHILE LIC. SUSP. UNDER  16-203, 16-206A2 FAIL TO ATTEND DIP, 17-106, 26-204/206, 27-103              1
# BRAKES ON TRUCK ARE INOPERATIVE, PARKING                                                                     1
# FAILURE OF DRIVER TO MAKE LANE CHANGE TO AVAIL. LANE NOT IMMED. ADJ. TO STOPPED EMERGENCY VEHICLE            1
# DRIVING VEH.,EQUIPMENT ON HWY WITH LAMP DEVICEIMPROPERLY DISPLAYING WHITE LIGHT FROM REAR                    1
# FAIL RETURN REG PLATE                                                                                        1
# DISPLAYING EXPIRED REGISTRATION PLATE ISSUED BY md                                                           1
# Name: Description, Length: 13133, dtype: int64
